# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
# %matplotlib inline

# %%
p2 = pd.read_csv('project_2.csv')

# %%
p2.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
# REQUIRES world-happiness-report-2021.csv

# You are expected to get a summarized happiness level for each country by combining all of the individual happiness 
# categories(Explained by: Log GDP per capita,Explained by: Social support,Explained by: Healthy life expectancy,
# Explained by: Freedom to make life choices,Explained by: Generosity,Explained by: Perceptions of corruption).

# Use the summarized happiness level to find solutions for the following.

# 1. What is Nigeria's position in the world happiness ranking.

# 2. Using an appropriate chart, compare Nigeria and United State's level of happiness.

# 3. What 3 attributes would you suggest to have the most influence on the summarized happiness level?
# Please show a linear model chart for each of these labels to proof their strong influence on summarized happiness
# level.

# 4. We want to know to predict how the happiness level of any given country would change with varying Ladder score, 
# Standard error of ladder score, upperwhisker, lowerwhisker, Logged GDP per capita, Social support,
# Healthy life expectancy,Freedom to make life choices, Generosity, Perceptions of corruption, Ladder score in Dystopia.
# Note: Please give a short explanation (written as a comment) for your choice classifier used to develop your model.

# 5. How happy would Nigeria be based on the following attribute scores (Ladder score=0.7.591, Standard error of 
# ladder score=0.043, upperwhisker=7.7, lowerwhisker=7.523, Logged GDP per capita=10.910, Social support0.901, 
# Healthy life expectancy=72.001,Freedom to make life choices=0.951, Generosity=0.101, Perceptions of corruption=0.177,
# Ladder score in Dystopia=2.430)

# %%
# 1. What is Nigeria's position in the world happiness ranking.

# %%
p2.drop(columns = {'Freedom to make life choices','Generosity','Perceptions of corruption','Ladder score in Dystopia','Logged GDP per capita','Social support','Healthy life expectancy'},inplace = True)

# %%
p2.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.446                         1.106
# 1                             1.502                         1.108
# 2                             1.566                         1.079
# ...

# %%
p2['Total Happiness'] = p2['Explained by: Perceptions of corruption'] + p2['Explained by: Generosity'] + p2['Explained by: Healthy life expectancy']+ p2['Explained by: Freedom to make life choices'] + p2['Explained by: Social support'] + p2['Explained by: Log GDP per capita']

# %%
p2.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.446                         1.106
# 1                             1.502                         1.108
# 2                             1.566                         1.079
# ...

# %%
p2[115:116]
# Out:
#     Country name  Regional indicator  Ladder score  \
# 115      Nigeria  Sub-Saharan Africa         4.759
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 115                           0.052         4.861         4.658
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 115                             0.663                         0.625
#
#      Explained by: Healthy life expectancy  \
# 115                                  0.051
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 115                                       0.433                     0.212
#
#      Explained by: Perceptions of corruption  Dystopia + residual  \
# 115                                    0.039                2.736
#
#      Total Happiness
# 115            2.023

# %%
p2['Total Happiness']
# Out:
# 0      4.589
# 1      4.752
# 2      4.731
# 3      4.587
# 4      4.666
#        ...
# 144    1.712
# 145    2.817
# 146    2.320
# 147    1.940
# 148    0.628
# Name: Total Happiness, Length: 149, dtype: float64

# %%
p2['max_rank'] = p2['Total Happiness'].rank(ascending = False)

# %%
p2
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
p2[115:116]
# Out:
#     Country name  Regional indicator  Ladder score  \
# 115      Nigeria  Sub-Saharan Africa         4.759
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 115                           0.052         4.861         4.658
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 115                             0.663                         0.625
#
#      Explained by: Healthy life expectancy  \
# 115                                  0.051
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 115                                       0.433                     0.212
#
#      Explained by: Perceptions of corruption  Dystopia + residual  \
# 115                                    0.039                2.736
#
#      Total Happiness  max_rank
# 115            2.023     127.0

# %%
#Therefore Nigeria Happiness Rank is 
p2[115:116]['max_rank']
# Out:
# 115    127.0
# Name: max_rank, dtype: float64

# %%
# 2. Using an appropriate chart, compare Nigeria and United State's level of happiness.

# %%
to = p2[115:116]
yo = p2[18:19]
pd.concat([yo,to])
# Out:
#       Country name     Regional indicator  Ladder score  \
# 18   United States  North America and ANZ         6.951
# 115        Nigeria     Sub-Saharan Africa         4.759
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 18                            0.049         7.047         6.856
# 115                           0.052         4.861         4.658
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 18                              1.533                         1.030
# 115                             0.663                         0.625
#
#      Explained by: Healthy life expectancy  \
# 18                                   0.621
# 115                                  0.051
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 18                                        0.554                     0.252
# 115                                       0.433                     0.212
#
# ...

# %%
index_names = ['1','2']
f = {'Total Happiness': [ 4.144   , 2.023], 'Countries':['United States','Nigeria']}

# %%
p3 = pd.DataFrame(f)

# %%
p3
# Out:
#    Total Happiness      Countries
# 0            4.144  United States
# 1            2.023        Nigeria

# %%
fig = plt.figure(figsize=(8,6))
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.set_title('Level of Happiness')

sn = sns.barplot(p3['Countries'],p3['Total Happiness'],estimator = max)
plt.setp(sn.get_xticklabels(),rotation = 0)

plt.show()
plt.tight_layout()

# %%
# 3. What 3 attributes would you suggest to have the most influence on the summarized happiness level?
# Please show a linear model chart for each of these labels to proof their strong influence on summarized happiness
# level.

# %%
sns.lmplot(x='Ladder score',y='Total Happiness',data = p2)

# %%
sns.lmplot(x='upperwhisker',y='Total Happiness',data = p2)

# %%
sns.lmplot(x='lowerwhisker',y='Total Happiness',data = p2)

# %%
# 4. We want to know to predict how the happiness level of any given country would change with varying Ladder score, 
# Standard error of ladder score, upperwhisker, lowerwhisker, Logged GDP per capita, Social support,
# Healthy life expectancy,Freedom to make life choices, Generosity, Perceptions of corruption, Ladder score in Dystopia.
# Note: Please give a short explanation (written as a comment) for your choice classifier used to develop your model.

# %%
p2.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual', 'Total Happiness', 'max_rank'],
#       dtype='object')

# %%
X = p2.drop(['Regional indicator','Country name','Total Happiness'],axis = 1)
y = p2['Total Happiness']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X[144:156]
# Out:
#      Ladder score  Standard error of ladder score  upperwhisker  lowerwhisker  \
# 144         3.512                           0.120         3.748         3.276
# 145         3.467                           0.074         3.611         3.322
# 146         3.415                           0.068         3.548         3.282
# 147         3.145                           0.058         3.259         3.030
# 148         2.523                           0.038         2.596         2.449
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 144                             0.451                         0.731
# 145                             1.099                         0.724
# 146                             0.364                         0.202
# 147                             0.457                         0.649
# 148                             0.370                         0.000
#
#      Explained by: Healthy life expectancy  \
# ...

# %%
#The reason for using Linear Regression as my classifier is because is best to estimate continous data(numeric data)not 
#discrete data 
#dependent variable is continous and easy to interprete result

# %%
# 5. How happy would Nigeria be based on the following attribute scores (Ladder score=0.7.591, Standard error of 
# ladder score=0.043, upperwhisker=7.7, lowerwhisker=7.523, Logged GDP per capita=10.910, Social support0.901, 
# Healthy life expectancy=72.001,Freedom to make life choices=0.951, Generosity=0.101, Perceptions of corruption=0.177,
# Ladder score in Dystopia=2.430)

# %%
index_names = ['1','2']
a = {'Ladder score': [0.7591],
'Standard error of ladder score' :[ 0.043],
'upperwhisker' : [7.7],
'lowerwhisker' : [7.523],
'Logged GDP per capita' : [10.910],
'Social support' : [0.901],
'Healthy life expectancy': [72.001],
'Freedom to make life choices' : [0.951],
'Generosity' :[ 0.101],
'Perceptions of corruption' :[ 0.177],
'Ladder score in Dystopia' : [2.430],}

# %%
p4 = pd.DataFrame(a)

# %%
p4
# Out:
#    Ladder score  Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0        0.7591                           0.043           7.7         7.523
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                  10.91           0.901                   72.001
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.951       0.101                      0.177
#
#    Ladder score in Dystopia
# 0                      2.43

# %%
p4['Total Happiness'] =p4['Logged GDP per capita'] + p4['Social support'] + p4['Healthy life expectancy'] + p4['Freedom to make life choices'] + p4['Generosity'] + p4['Perceptions of corruption'] + p4['Ladder score in Dystopia']

# %%
#THEREFORE NIGERIA NEW HAPPINESS SCORE FOR NIGERIA IS:
p4['Total Happiness']
# Out:
# 0    87.471
# Name: Total Happiness, dtype: float64
